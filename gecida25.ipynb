# %% [markdown]
# <a href="https://colab.research.google.com/github/Renan2004a/Gecida_25/blob/main/gecida25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd      # manipulação e análise de dados tabulares (DataFrame, tipo planilha)
import numpy as np       # cálculos numéricos e vetorizados (arrays, matrizes, estatística)
import matplotlib.pyplot as plt # criação de gráficos básicos (linhas, barras, dispersão, histogramas)
import seaborn as sns    # gráficos estatísticos (heatmap, boxplot, etc.)
import kagglehub # baixar datasets e modelos direto do Kaggle
import os # manipulação de arquivos e diretórios
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import StratifiedKFold, cross_validate
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# #Teste

# %%
test = (pd.read_csv('/content/drive/MyDrive/gecida25/test.csv'))

# %%
test.head()
# Out:
#    Id  minutes_past  radardist_km   Ref  Ref_5x5_10th  Ref_5x5_50th  \
# 0   1             1           8.0   NaN           NaN           NaN
# 1   1             5           8.0  10.0           NaN          10.0
# 2   1             8           8.0   NaN           NaN           7.0
# 3   1            12           8.0  14.0           NaN           9.0
# 4   1            15           8.0  10.5           NaN           9.0
#
#    Ref_5x5_90th  RefComposite  RefComposite_5x5_10th  RefComposite_5x5_50th  \
# 0          14.0           NaN                    NaN                    NaN
# 1          18.0          11.5                    NaN                   11.0
# 2          14.5           NaN                    NaN                    7.0
# 3          16.0          14.0                    NaN                    9.0
# 4          15.5          13.5                    NaN                    9.0
#
#    ...  RhoHV_5x5_50th  RhoHV_5x5_90th  Zdr  Zdr_5x5_10th  Zdr_5x5_50th  \
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8022756 entries, 0 to 8022755
# Data columns (total 23 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Id                     int64
#  1   minutes_past           int64
#  2   radardist_km           float64
#  3   Ref                    float64
#  4   Ref_5x5_10th           float64
#  5   Ref_5x5_50th           float64
#  6   Ref_5x5_90th           float64
#  7   RefComposite           float64
#  8   RefComposite_5x5_10th  float64
#  9   RefComposite_5x5_50th  float64
#  10  RefComposite_5x5_90th  float64
#  11  RhoHV                  float64
#  12  RhoHV_5x5_10th         float64
#  13  RhoHV_5x5_50th         float64
#  14  RhoHV_5x5_90th         float64
#  15  Zdr                    float64
#  16  Zdr_5x5_10th           float64
#  17  Zdr_5x5_50th           float64
#  18  Zdr_5x5_90th           float64
#  19  Kdp                    float64
#  20  Kdp_5x5_10th           float64
# ...

# %%
test.describe()
# Out:
#                  Id  minutes_past  radardist_km           Ref  Ref_5x5_10th  \
# count  8.022756e+06  8.022756e+06  8.022756e+06  3.663128e+06  3.067995e+06
# mean   3.606618e+05  2.950236e+01  1.103318e+01  2.241068e+01  1.954005e+01
# std    2.079306e+05  1.731434e+01  4.191674e+00  9.978445e+00  8.924519e+00
# min    1.000000e+00  0.000000e+00  0.000000e+00 -2.700000e+01 -3.050000e+01
# 25%    1.813690e+05  1.500000e+01  9.000000e+00  1.600000e+01  1.400000e+01
# 50%    3.606580e+05  2.900000e+01  1.100000e+01  2.200000e+01  1.950000e+01
# 75%    5.422930e+05  4.400000e+01  1.400000e+01  2.900000e+01  2.550000e+01
# max    7.176250e+05  5.900000e+01  2.100000e+01  7.150000e+01  6.750000e+01
#
#        Ref_5x5_50th  Ref_5x5_90th  RefComposite  RefComposite_5x5_10th  \
# count  3.668089e+06  4.340793e+06  3.839046e+06           3.294829e+06
# mean   2.210822e+01  2.531447e+01  2.411047e+01           2.164715e+01
# ...

# %%
valores_vazios = test.isnull().sum()
print("Variáveis com valores vazios:")
print(valores_vazios[valores_vazios > 0])
# Out:
# Variáveis com valores vazios:
# Ref                      4359628
# Ref_5x5_10th             4954761
# Ref_5x5_50th             4354667
# Ref_5x5_90th             3681963
# RefComposite             4183710
# RefComposite_5x5_10th    4727927
# RefComposite_5x5_50th    4185824
# RefComposite_5x5_90th    3549123
# RhoHV                    5074300
# RhoHV_5x5_10th           5545827
# RhoHV_5x5_50th           5071970
# RhoHV_5x5_90th           4505051
# Zdr                      5074300
# Zdr_5x5_10th             5545827
# Zdr_5x5_50th             5071970
# Zdr_5x5_90th             4505051
# Kdp                      5502140
# Kdp_5x5_10th             5956185
# Kdp_5x5_50th             5498259
# Kdp_5x5_90th             4984768
# dtype: int64

# %% [markdown]
# #Treino

# %%
train = (pd.read_csv('/content/drive/MyDrive/gecida25/train.csv'))

# %%
train.head()
# Out:
#    Id  minutes_past  radardist_km  Ref  Ref_5x5_10th  Ref_5x5_50th  \
# 0   1             3          10.0  NaN           NaN           NaN
# 1   1            16          10.0  NaN           NaN           NaN
# 2   1            25          10.0  NaN           NaN           NaN
# 3   1            35          10.0  NaN           NaN           NaN
# 4   1            45          10.0  NaN           NaN           NaN
#
#    Ref_5x5_90th  RefComposite  RefComposite_5x5_10th  RefComposite_5x5_50th  \
# 0           NaN           NaN                    NaN                    NaN
# 1           NaN           NaN                    NaN                    NaN
# 2           NaN           NaN                    NaN                    NaN
# 3           NaN           NaN                    NaN                    NaN
# 4           NaN           NaN                    NaN                    NaN
#
#    ...  RhoHV_5x5_90th  Zdr  Zdr_5x5_10th  Zdr_5x5_50th  Zdr_5x5_90th  Kdp  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13765201 entries, 0 to 13765200
# Data columns (total 24 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Id                     int64
#  1   minutes_past           int64
#  2   radardist_km           float64
#  3   Ref                    float64
#  4   Ref_5x5_10th           float64
#  5   Ref_5x5_50th           float64
#  6   Ref_5x5_90th           float64
#  7   RefComposite           float64
#  8   RefComposite_5x5_10th  float64
#  9   RefComposite_5x5_50th  float64
#  10  RefComposite_5x5_90th  float64
#  11  RhoHV                  float64
#  12  RhoHV_5x5_10th         float64
#  13  RhoHV_5x5_50th         float64
#  14  RhoHV_5x5_90th         float64
#  15  Zdr                    float64
#  16  Zdr_5x5_10th           float64
#  17  Zdr_5x5_50th           float64
#  18  Zdr_5x5_90th           float64
#  19  Kdp                    float64
#  20  Kdp_5x5_10th           float64
# ...

# %%
train.describe()
# Out:
#                  Id  minutes_past  radardist_km           Ref  Ref_5x5_10th  \
# count  1.376520e+07  1.376520e+07  1.376520e+07  6.349375e+06  5.283988e+06
# mean   5.923370e+05  2.952373e+01  1.106794e+01  2.292666e+01  1.995227e+01
# std    3.408561e+05  1.730813e+01  4.206618e+00  1.035516e+01  9.208166e+00
# min    1.000000e+00  0.000000e+00  0.000000e+00 -3.100000e+01 -3.200000e+01
# 25%    2.968970e+05  1.500000e+01  9.000000e+00  1.600000e+01  1.400000e+01
# 50%    5.921990e+05  3.000000e+01  1.100000e+01  2.250000e+01  2.000000e+01
# 75%    8.895820e+05  4.400000e+01  1.400000e+01  2.950000e+01  2.600000e+01
# max    1.180945e+06  5.900000e+01  2.100000e+01  7.100000e+01  6.250000e+01
#
#        Ref_5x5_50th  Ref_5x5_90th  RefComposite  RefComposite_5x5_10th  \
# count  6.356482e+06  7.551281e+06  6.716343e+06           5.755673e+06
# mean   2.261029e+01  2.589846e+01  2.471108e+01           2.215824e+01
# ...

# %%
valores_vazios = train.isnull().sum()
print("Variáveis com valores vazios:")
print(valores_vazios[valores_vazios > 0])
# Out:
# Variáveis com valores vazios:
# Ref                       7415826
# Ref_5x5_10th              8481213
# Ref_5x5_50th              7408719
# Ref_5x5_90th              6213920
# RefComposite              7048858
# RefComposite_5x5_10th     8009528
# RefComposite_5x5_50th     7053538
# RefComposite_5x5_90th     5935998
# RhoHV                     8830285
# RhoHV_5x5_10th            9632047
# RhoHV_5x5_50th            8828633
# RhoHV_5x5_90th            7859617
# Zdr                       8830285
# Zdr_5x5_10th              9632047
# Zdr_5x5_50th              8828633
# Zdr_5x5_90th              7859617
# Kdp                       9582566
# Kdp_5x5_10th             10336419
# Kdp_5x5_50th              9577920
# Kdp_5x5_90th              8712425
# dtype: int64
